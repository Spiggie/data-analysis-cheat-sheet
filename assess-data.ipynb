# %% [markdown]
# # Assess data

# %% [markdown]
# ## Imports
# Do some imports we need for working with the data.

# %%
import pandas as pd

# %%
# Read a file to see data
df = pd.read_csv('data\earthquakes.csv')
df.head()
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2018-05-21T11:49:32.154Z  61.453500 -149.949000  33.50  1.40      ml   NaN
# 1  2018-05-21T11:40:47.790Z  33.505833 -116.793500   5.20  0.58      ml  24.0
# 2  2018-05-21T11:38:45.464Z  62.944100 -148.503500   4.50  1.60      ml   NaN
# 3  2018-05-21T11:35:59.820Z  37.675835 -118.851166  -0.67  1.07      md  10.0
# 4  2018-05-21T11:25:51.080Z  33.487667 -116.793833   2.12  0.28      ml  16.0
#
#      gap     dmin   rms    ...                      updated  \
# 0    NaN      NaN  0.21    ...     2018-05-21T11:54:44.040Z
# 1   47.0  0.07572  0.17    ...     2018-05-21T11:44:24.630Z
# 2    NaN      NaN  0.74    ...     2018-05-21T11:46:50.269Z
# 3  181.0  0.02885  0.07    ...     2018-05-21T11:58:01.451Z
# 4   61.0  0.09078  0.14    ...     2018-05-21T11:29:32.456Z
#
#                            place        type horizontalError depthError  \
# ...

# %% [markdown]
# ## Data overview

# %%
# returns a tuple of the dimensions of the dataframe
df.shape
# Out:
# (11903, 22)

# %%
# returns the data types of the columns
df.dtypes
# Out:
# time                object
# latitude           float64
# longitude          float64
# depth              float64
# mag                float64
# magType             object
# nst                float64
# gap                float64
# dmin               float64
# rms                float64
# net                 object
# id                  object
# updated             object
# place               object
# type                object
# horizontalError    float64
# depthError         float64
# magError           float64
# magNst             float64
# status              object
# locationSource      object
# magSource           object
# dtype: object

# %%
# although the datatype might be shown as an object, it could be something else
# this is because pandas uses pointers...
type(df['time'][0])
# Out:
# str

# %%
# show a concise summary of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11903 entries, 0 to 11902
# Data columns (total 22 columns):
# time               11903 non-null object
# latitude           11903 non-null float64
# longitude          11903 non-null float64
# depth              11903 non-null float64
# mag                11902 non-null float64
# magType            11902 non-null object
# nst                8372 non-null float64
# gap                9348 non-null float64
# dmin               9321 non-null float64
# rms                11862 non-null float64
# net                11903 non-null object
# id                 11903 non-null object
# updated            11903 non-null object
# place              11903 non-null object
# type               11903 non-null object
# horizontalError    8482 non-null float64
# depthError         11865 non-null float64
# magError           9073 non-null float64
# magNst             9251 non-null float64
# status             11903 non-null object
# ...

# %%
# returns the number of unique values in each column
df.nunique()
# Out:
# time               11901
# latitude            9601
# longitude          10001
# depth               3056
# mag                  453
# magType               10
# nst                  132
# gap                 1182
# dmin                6781
# rms                  817
# net                   14
# id                 11903
# updated            11903
# place               5985
# type                   7
# horizontalError      538
# depthError           721
# magError             761
# magNst               206
# status                 2
# locationSource        16
# magSource             18
# dtype: int64

# %%
# get some basic useful descriptive statistics for each valid column
df.describe()
# Out:
#            latitude     longitude         depth           mag          nst  \
# count  11903.000000  11903.000000  11903.000000  11902.000000  8372.000000
# mean      36.178398   -124.657591     17.846070      1.676422    19.764811
# std       18.332939     52.139256     43.993906      1.112906    16.045583
# min      -60.522000   -179.984400     -3.370000     -0.950000     0.000000
# 25%       19.433000   -154.901253      2.020000      0.870000     9.000000
# 50%       36.889500   -122.821667      5.990000      1.500000    15.000000
# 75%       46.867667   -116.885600     12.500000      2.270000    25.000000
# max       81.610700    179.950300    638.260000      6.900000   280.000000
#
#                gap         dmin           rms  horizontalError    depthError  \
# count  9348.000000  9321.000000  11862.000000      8482.000000  11865.000000
# mean    127.597824     0.414841      0.271099         1.456160      2.392046
# ...

# %%
# show the first rows of the dataframe (# of columns can be specified; if not specified, 5 columns are shown)
df.head()
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2018-05-21T11:49:32.154Z  61.453500 -149.949000  33.50  1.40      ml   NaN
# 1  2018-05-21T11:40:47.790Z  33.505833 -116.793500   5.20  0.58      ml  24.0
# 2  2018-05-21T11:38:45.464Z  62.944100 -148.503500   4.50  1.60      ml   NaN
# 3  2018-05-21T11:35:59.820Z  37.675835 -118.851166  -0.67  1.07      md  10.0
# 4  2018-05-21T11:25:51.080Z  33.487667 -116.793833   2.12  0.28      ml  16.0
#
#      gap     dmin   rms    ...                      updated  \
# 0    NaN      NaN  0.21    ...     2018-05-21T11:54:44.040Z
# 1   47.0  0.07572  0.17    ...     2018-05-21T11:44:24.630Z
# 2    NaN      NaN  0.74    ...     2018-05-21T11:46:50.269Z
# 3  181.0  0.02885  0.07    ...     2018-05-21T11:58:01.451Z
# 4   61.0  0.09078  0.14    ...     2018-05-21T11:29:32.456Z
#
#                            place        type horizontalError depthError  \
# ...

# %%
# show the last rows of the dataframe (# of columns can be specified; if not specified, 5 columns are shown)
df.tail()
# Out:
#                            time   latitude   longitude  depth   mag magType  \
# 11898  2018-04-21T12:34:49.030Z  19.388500 -155.279007   0.69  2.09      ml
# 11899  2018-04-21T12:29:19.890Z  37.574333 -119.076167   3.34  0.47      md
# 11900  2018-04-21T12:29:14.910Z  38.786333 -122.765167   1.78  1.04      md
# 11901  2018-04-21T12:16:49.275Z  59.732300 -136.181500   3.40  1.20      ml
# 11902  2018-04-21T12:13:33.182Z  60.303200 -141.665600  15.60  2.60      ml
#
#         nst    gap     dmin   rms    ...                      updated  \
# 11898  28.0   58.0  0.00322  0.30    ...     2018-04-21T12:40:35.820Z
# 11899  17.0  273.0  0.02722  0.04    ...     2018-04-23T07:23:58.777Z
# 11900  29.0   92.0  0.01560  0.07    ...     2018-04-23T07:09:56.705Z
# 11901   NaN    NaN      NaN  0.68    ...     2018-04-25T23:45:36.344Z
# 11902   NaN    NaN      NaN  0.71    ...     2018-04-28T06:48:59.040Z
#
#                                    place        type horizontalError  \
# ...

# %% [markdown]
# ## Indexing and Selecting Data in Pandas

# %%
# show index number and label for each column
for i, v in enumerate(df.columns):
    print(i, v)
# Out:
# 0 time
# 1 latitude
# 2 longitude
# 3 depth
# 4 mag
# 5 magType
# 6 nst
# 7 gap
# 8 dmin
# 9 rms
# 10 net
# 11 id
# 12 updated
# 13 place
# 14 type
# 15 horizontalError
# 16 depthError
# 17 magError
# 18 magNst
# 19 status
# 20 locationSource
# 21 magSource

# %% [markdown]
# We can select data using `loc` and `iloc`, which you can read more about [here](https://pandas.pydata.org/pandas-docs/stable/indexing.html). `loc` uses labels of rows or columns to select data, while `iloc` uses the index numbers. We'll use these to index the dataframe below.

# %%
# select a subset of the columns, specified by name
df.loc[:, 'time':'mag']
# Out:
#                            time   latitude   longitude  depth   mag
# 0      2018-05-21T11:49:32.154Z  61.453500 -149.949000  33.50  1.40
# 1      2018-05-21T11:40:47.790Z  33.505833 -116.793500   5.20  0.58
